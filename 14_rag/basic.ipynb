# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.llms.openai import OpenAI

# 環境変数の取得
load_dotenv("../.env")
os.environ['OPENAI_API_KEY']  = os.environ['API_KEY']

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# ドキュメントからテキスト情報を読込
documents = SimpleDirectoryReader('./data/text').load_data()

# インデックスの構築
index = VectorStoreIndex.from_documents(documents)
# Out:
# Retrying llama_index.embeddings.openai.base.OpenAIEmbedding._get_text_embeddings.<locals>._retryable_get_embeddings in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 5
#       2 documents = SimpleDirectoryReader('./data/text').load_data()
#       4 # インデックスの構築
# ----> 5 index = VectorStoreIndex.from_documents(documents)
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\core\indices\base.py:122, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, **kwargs)
#     113     docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#     115 nodes = run_transformations(
#     116     documents,  # type: ignore
#     117     transformations,
#     118     show_progress=show_progress,
#     119     **kwargs,
#     120 )
# --> 122 return cls(
#     123     nodes=nodes,
#     124     storage_context=storage_context,
#     125     callback_manager=callback_manager,
#     126     show_progress=show_progress,
#     127     transformations=transformations,
#     128     **kwargs,
#     129 )
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\core\indices\vector_store\base.py:77, in VectorStoreIndex.__init__(self, nodes, use_async, store_nodes_override, embed_model, insert_batch_size, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      70 self._embed_model = (
#      71     resolve_embed_model(embed_model, callback_manager=callback_manager)
#      72     if embed_model
#      73     else Settings.embed_model
#      74 )
#      76 self._insert_batch_size = insert_batch_size
# ---> 77 super().__init__(
#      78     nodes=nodes,
#      79     index_struct=index_struct,
#      80     storage_context=storage_context,
#      81     show_progress=show_progress,
#      82     objects=objects,
#      83     callback_manager=callback_manager,
#      84     transformations=transformations,
#      85     **kwargs,
#      86 )
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\core\indices\base.py:79, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      77 if index_struct is None:
#      78     nodes = nodes or []
# ---> 79     index_struct = self.build_index_from_nodes(
#      80         nodes + objects,  # type: ignore
#      81         **kwargs,  # type: ignore
#      82     )
#      83 self._index_struct = index_struct
#      84 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\core\indices\vector_store\base.py:311, in VectorStoreIndex.build_index_from_nodes(self, nodes, **insert_kwargs)
#     308 if len(content_nodes) != len(nodes):
#     309     print("Some nodes are missing content, skipping them...")
# --> 311 return self._build_index_from_nodes(content_nodes, **insert_kwargs)
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\core\indices\vector_store\base.py:280, in VectorStoreIndex._build_index_from_nodes(self, nodes, **insert_kwargs)
#     278     run_async_tasks(tasks)
#     279 else:
# --> 280     self._add_nodes_to_index(
#     281         index_struct,
#     282         nodes,
#     283         show_progress=self._show_progress,
#     284         **insert_kwargs,
#     285     )
#     286 return index_struct
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\core\indices\vector_store\base.py:233, in VectorStoreIndex._add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     230     return
#     232 for nodes_batch in iter_batch(nodes, self._insert_batch_size):
# --> 233     nodes_batch = self._get_node_with_embedding(nodes_batch, show_progress)
#     234     new_ids = self._vector_store.add(nodes_batch, **insert_kwargs)
#     236     if not self._vector_store.stores_text or self._store_nodes_override:
#     237         # NOTE: if the vector store doesn't store text,
#     238         # we need to add the nodes to the index struct and document store
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\core\indices\vector_store\base.py:140, in VectorStoreIndex._get_node_with_embedding(self, nodes, show_progress)
#     128 def _get_node_with_embedding(
#     129     self,
#     130     nodes: Sequence[BaseNode],
#     131     show_progress: bool = False,
#     132 ) -> List[BaseNode]:
#     133     """
#     134     Get tuples of id, node, and embedding.
#     135
#    (...)    138
#     139     """
# --> 140     id_to_embed_map = embed_nodes(
#     141         nodes, self._embed_model, show_progress=show_progress
#     142     )
#     144     results = []
#     145     for node in nodes:
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\core\indices\utils.py:164, in embed_nodes(nodes, embed_model, show_progress)
#     161     else:
#     162         id_to_embed_map[node.node_id] = node.embedding
# --> 164 new_embeddings = embed_model.get_text_embedding_batch(
#     165     texts_to_embed, show_progress=show_progress
#     166 )
#     168 for new_id, text_embedding in zip(ids_to_embed, new_embeddings):
#     169     id_to_embed_map[new_id] = text_embedding
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:324, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     321             _logger.debug(f"Failed to reset active_span_id: {e}")
#     323 try:
# --> 324     result = func(*args, **kwargs)
#     325     if isinstance(result, asyncio.Future):
#     326         # If the result is a Future, wrap it
#     327         new_future = asyncio.ensure_future(result)
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\core\base\embeddings\base.py:335, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     326 dispatcher.event(
#     327     EmbeddingStartEvent(
#     328         model_dict=model_dict,
#     329     )
#     330 )
#     331 with self.callback_manager.event(
#     332     CBEventType.EMBEDDING,
#     333     payload={EventPayload.SERIALIZED: self.to_dict()},
#     334 ) as event:
# --> 335     embeddings = self._get_text_embeddings(cur_batch)
#     336     result_embeddings.extend(embeddings)
#     337     event.on_end(
#     338         payload={
#     339             EventPayload.CHUNKS: cur_batch,
#     340             EventPayload.EMBEDDINGS: embeddings,
#     341         },
#     342     )
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\embeddings\openai\base.py:465, in OpenAIEmbedding._get_text_embeddings(self, texts)
#     456 @retry_decorator
#     457 def _retryable_get_embeddings():
#     458     return get_embeddings(
#     459         client,
#     460         texts,
#     461         engine=self._text_engine,
#     462         **self.additional_kwargs,
#     463     )
# --> 465 return _retryable_get_embeddings()
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\tenacity\__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\embeddings\openai\base.py:458, in OpenAIEmbedding._get_text_embeddings.<locals>._retryable_get_embeddings()
#     456 @retry_decorator
#     457 def _retryable_get_embeddings():
# --> 458     return get_embeddings(
#     459         client,
#     460         texts,
#     461         engine=self._text_engine,
#     462         **self.additional_kwargs,
#     463     )
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\llama_index\embeddings\openai\base.py:169, in get_embeddings(client, list_of_text, engine, **kwargs)
#     165 assert len(list_of_text) <= 2048, "The batch size should not be larger than 2048."
#     167 list_of_text = [text.replace("\n", " ") for text in list_of_text]
# --> 169 data = client.embeddings.create(input=list_of_text, model=engine, **kwargs).data
#     170 return [d.embedding for d in data]
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\openai\resources\embeddings.py:128, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     122             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     123                 base64.b64decode(data), dtype="float32"
#     124             ).tolist()
#     126     return obj
# --> 128 return self._post(
#     129     "/embeddings",
#     130     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     131     options=make_request_options(
#     132         extra_headers=extra_headers,
#     133         extra_query=extra_query,
#     134         extra_body=extra_body,
#     135         timeout=timeout,
#     136         post_parser=parser,
#     137     ),
#     138     cast_to=CreateEmbeddingResponse,
#     139 )
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\openai\_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)   1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\1014559\Documents\llmdev\.venv\Lib\site-packages\openai\_base_client.py:1034, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1031             err.response.read()
#    1033         log.debug("Re-raising status error")
# -> 1034         raise self._make_status_error_from_response(err.response) from None
#    1036     break
#    1038 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
# Chat Engineの作成
llm = OpenAI(model=MODEL_NAME)
chat_engine = index.as_chat_engine(chat_mode="openai", llm=llm, verbose=True)

# %%
# 質問：1回目
response = chat_engine.chat("有給休暇はいつから取得できますか？")

# 言語モデルからの回答を表示
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 質問：1回目
# ----> 2 response = chat_engine.chat("有給休暇はいつから取得できますか？")
#       4 # 言語モデルからの回答を表示
#       5 print(response)
#
# NameError: name 'chat_engine' is not defined

# %%
# 引用元を表示
for source in response.sources:
    for source_node in source.raw_output.source_nodes:
        print("ファイル名：", source_node.metadata['file_name'])
        print("関連度スコア：", source_node.score)
        print("テキスト：")
        print(source_node.node.text)
        print("-" * 50) # 区切り線

# %%
# 質問：2回目
response = chat_engine.chat("勤続年数が5年の場合は何日ですか？")

# 言語モデルからの回答を表示
print(response)

# %%
# 引用元を表示
for source in response.source_nodes:
    for source_node in source.raw_output.source_nodes:
        print("ファイル名：", source_node.metadata['file_name'])
        print("関連度スコア：", source_node.score)
        print("テキスト：")
        print(source_node.node.text)
        print("-" * 50)
